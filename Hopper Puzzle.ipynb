# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

# %%
data.head()
# Out:
#          A         B
# 0  0.39715  2.113629
# 1  0.39715  2.113629
# 2  0.39715  2.113629
# 3  0.39715  2.113629
# 4  0.39715  2.113629

# %%
data.describe()
# Out:
#                  A            B
# count  1023.000000  1023.000000
# mean      0.504834    -0.390610
# std       0.355265     1.498035
# min      -0.925070    -2.837888
# 25%       0.389602    -1.559230
# 50%       0.592344    -1.130949
# 75%       0.746599     0.572017
# max       1.195399     3.096964

# %%
data.corr()
# Out:
#           A         B
# A  1.000000 -0.247559
# B -0.247559  1.000000

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, aspect = 2)

# %%
sns.pairplot(data, size = 7, aspect = 2)
